# %%
def creating_an_equation()
# 1. create an equation
# 2. take one eq and turn it into x or y only and rest on rhs
# 3. put that x or y in second equation and solve it
# 4. what if there are more than three equations
# 5. use elimination as a second function
# 6. use +,-,*
# 7. return a tuple with x and y coordinates
